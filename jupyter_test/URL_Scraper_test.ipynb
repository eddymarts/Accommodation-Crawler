# %%
areas_of_UK = ["London", "South East England", "East Midlands", "East of England", "North East England", "North West England", "South West England", "West Midlands", "Yorkshire and The Humber", "Isle of Man", "Channel Isles", "Scotland", "Wales", "Northern Ireland"]

# %%
def scrape_URLs_for_region(region):
    url = f"https://www.zoopla.co.uk/to-rent/property/london/?page_size=25&price_frequency=per_month&q=london&radius=0&results_sort=newest_listings&pn=2#listing_58997893"
    return region

def find(number_to_find=None):
    # finds URLs and saves them to the DB.
    for region in areas_of_UK:
        scrape_URLs_for_region(region)
    


find()

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = f"https://www.zoopla.co.uk/to-rent/property/London/?page_size=50&price_frequency=per_month&q=London&radius=0&results_sort=newest_listings&pn=6111"
print(url)

page = requests.get(url)
soup = BeautifulSoup(page.content)

urls = [item for item in soup.find_all('a', attrs={'data-testid' : True}) if item['data-testid']=='listing-details-link']
for a in urls:
    print(a['href'])
# Out:
# https://www.zoopla.co.uk/to-rent/property/London/?page_size=50&price_frequency=per_month&q=London&radius=0&results_sort=newest_listings&pn=6111

# %%
url = f"https://www.zoopla.co.uk/for-sale/details/59013492/"
print(url)

page = requests.get(url)
soup = BeautifulSoup(page.content)
print(page.status_code)
# Out:
# https://www.zoopla.co.uk/for-sale/details/59013492/
# 200

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-GB"><head><script type="text/javascript">
# ;window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true,cors_use_newrelic_header:true,cors_use_tracecontext_headers:false,allowed_origins:['https://api-graphql-lambda.integ.zoopla.co.uk']},privacy:{cookies_enabled:true}};
# window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(27),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{l?l-=1:o(c||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(28),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(l+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){_++,T=g.hash,this[u]=y.now()}function o(){_--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,p="cb"+c,l="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),M=t(14),P=t(9),S=t("ee"),C=S.get("tracer");t(16),y.features.spa=!0;var T,_=0;S.on(u,r),S.on(p,r),S.on(d,o),S.on(l,o),S.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),M.buffer([u,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+f+c,m+f+s]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+c]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(M,"send-xhr"+c),a(S,"xhr-resolved"),a(S,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,_>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),o.on(g+l,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),o.on(g+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.per ...
# ;NREUM.loader_config={accountID:"2902499",trustKey:"2902499",agentID:"95776729",licenseKey:"NRJS-87cb4c448aca56623be",applicationID:"95776729"}
# ;NREUM.info={beacon:"bam.eu01.nr-data.net",errorBeacon:"bam.eu01.nr-data.net",licenseKey:"NRJS-87cb4c448aca56623be",applicationID:"95776729",sa:1}
#     </script><style data-emotion="css-global 1tgn2dr">body{margin:0;font-family:Lato,Helvetica,Arial,sans-serif;box-sizing:border-box;line-height:1.15;-webkit-text-size-adjust:100%;}@font-face{font-family:Lato;font-style:normal;font-weight:normal;font-display:swap;src:local('Lato'),url('/fonts/LatoLatin-Regular.woff2') format('woff2'),url('/fonts/LatoLatin-Regular.woff') format('woff');}@font-face{font-family:Lato;font-style:normal;font-weight:bold;font-display:swap;src:local('Lato'),local('Lato'),url('/fonts/LatoLatin-Bold.woff2') format('woff2'),url('/fonts/LatoLatin-Bold.woff') format('woff');}@font-face{font-family:'ZooplaDisplay';font-style:normal;font-weight:normal;font-display:swap;src:local('ZooplaDisplay'),url('/fonts/ZooplaDisplay-Regular.woff2') format('woff2'),url('/fonts/ZooplaDisplay-Regular.woff') format('woff');}@font-face{font-family:'ZooplaDisplay';font-style:normal;font-weight:bold;font-display:swap;src:local('ZooplaDisplay'),url('/fonts/ZooplaDisplay-Bold.woff2') format('woff2'),url('/fonts/ZooplaDisplay-Bold.woff') format('woff');}*,*:before,*:after{box-sizing:inherit;}@media (prefers-reduced-motion: reduce){*{-webkit-animation:none!important;animation:none!important;transition-property:none!important;}}</style><link as="font" crossorigin="anonymous" href="/fonts/LatoLatin-Regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/fonts/LatoLatin-Bold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/fonts/ZooplaDisplay-Regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/fonts/ZooplaDisplay-Bold.woff2" rel="preload" type="font/woff2"/><link href="https://r.zoocdn.com" rel="preconnect"/><link href="https://lid.zoocdn.com" rel="preconnect"/><script data-testid="inline-script">
#     window.dataLayer = window.dataLayer || [];
# </script><script data-testid="inline-script">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-WNFR4ZC');</script><script data-testid="inline-script">(!function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on","addSourceMiddleware","addIntegrationMiddleware","setAnonymousId","addDestinationMiddleware"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t,e){var n=document.createElement("script");n.type="text/javascript";n.async=!0;n.src="https://cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(n,a);analytics._loadOptions=e};analytics.SNIPPET_VERSION="4.1.0";
#         analytics.load('kMettuB218zyYLIzUsT2ptxdGiEtWYT2');
#         analytics.setAnonymousId('2b0c24af-77da-4109-93c0-31261414c8bf');
#     }}())</script><script async="" data-testid="baselayer-script" defer="" src="https://scripts.prod.zoopla.co.uk/baselayer.min.0.0.6.js"></script><script async="" data-testid="advert_ext_partner_script" src="//js-sec.indexww.com/ht/p/185636-228001238555025.js"></script><script async="" data-testid="advert_dfp_script" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><title>2 bed cottage for sale in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7 - Zoopla</title><meta content="2 bed cottage for sale in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7, selling for £435,000 from Rural View Residential Sales and Lettings. See property details on Zoopla or browse all our range of properties in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7." name="description"/><link href="https://www.zoopla.co.uk/for-sale/details/59013492/" rel="canonical"/><link href="https://r.zoocdn.com/_next/static/images/apple-touch-icon-eef704c016bbaf62cf0574a23498d706.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://r.zoocdn.com/_next/static/images/favicon-32x32-47512d065ffbc2687a7285987d615e7f.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://r.zoocdn.com/_next/static/images/favicon-16x16-239658ffb005d4c676f5cb072893cc1a.png" rel="icon" sizes="16x16" type="image/png"/><link href="https://r.zoocdn.com/_next/static/images/favicon-b2be8fc5a988bfb80c434b03cb9b6708.ico" rel="shortcut icon"/><link href="https://r.zoocdn.com/_next/static/other/site-d65fcd3db1233f186446d63ebfd0a1ea.webmanifest" rel="manifest"/><link color="#8046f1" href="https://r.zoocdn.com/_next/static/images/safari-pinned-tab-cfc4a2c98ae0696bcc7f4a44158c3d1b.svg" rel="mask-icon"/><meta content="https://r.zoocdn.com/_next/static/other/browserconfig-984c73468b8ad06e2fa0d6eb067e975d.xml" name="msapplication-config"/><meta content="#8046f1" name="msapplication-TileColor"/><meta content="#ffffff" name="theme-color"/><meta content="summary" name="twitter:card"/><meta content="zoopla" name="twitter:app:name:iphone"/><meta content="380932800" name="twitter:app:id:iphone"/><meta content="zoopla" name="twitter:app:name:googleplay"/><meta content="com.zoopla.activity" name="twitter:app:id:googleplay"/><meta content="zoopla:///for-sale/details/59013492/" name="twitter:app:url:iphone"/><meta content="android-app://com.zoopla.activity/zoopla/for-sale/details/59013492/" name="twitter:app:url:googleplay"/><meta content="100003926523449" property="fb:admins"/><meta content="19903963" property="twitter:account_id"/><meta content="https://www.zoopla.co.uk/for-sale/details/59013492/" property="og:url"/><meta content="2 bed cottage for sale in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7 - Zoopla" property="og:title"/><meta content="website" property="og:type"/><meta content="https://lid.zoocdn.com/1024/768/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg" property="og:image"/><meta content="2 bed cottage for sale in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7, selling for £435,000 from Rural View Residential Sales and Lettings. See property details on Zoopla or browse all our range of properties in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7." property="og:description"/><script type="application/ld+json">{
# 	"@context": "http://schema.org",
# 	"@graph": [
# 		{
# 			"@type": "WebSite",
# 			"name": "Zoopla",
# 			"alternateName": "Zoopla Property Search",
# 			"url": "https://www.zoopla.co.uk/"
# 		},
# 		{
# 			"@type": "RealEstateAgent",
# 			"name": "Rural View Residential Sales and Lettings",
# 			"url": "https://www.zoopla.co.uk/find-agents/branch/rural-view-residential-sales-and-lettings-salisbury-43866/",
# 			"logo": {
# 				"@type": "ImageObject",
# 				"contentUrl": "https://st.zoocdn.com/zoopla_static_agent_logo_(674742).png"
# 			},
# 			"image": "https://st.zoocdn.com/zoopla_static_agent_logo_(674742).png",
# 			"address": {
# 				"@type": "PostalAddress"
# 			},
# 			"telephone": "01722 515010"
# 		},
# 		{
# 			"@context": "http://schema.org",
# 			"breadcrumb": {
# 				"itemListElement": [
# 					{
# 						"position": 1,
# 						"item": {
# 							"name": "Zoopla",
# 							"@id": "https://www.zoopla.co.uk/"
# 						},
# 						"@type": "ListItem"
# 					},
# 					{
# 						"position": 2,
# 						"item": {
# 							"name": "For sale",
# 							"@id": "https://www.zoopla.co.uk/for-sale/"
# 						},
# 						"@type": "ListItem"
# 					},
# 					{
# 						"position": 3,
# 						"item": {
# 							"name": "Dorset",
# 							"@id": "https://www.zoopla.co.uk/for-sale/property/dorset/"
# 						},
# 						"@type": "ListItem"
# 					},
# 					{
# 						"position": 4,
# 						"item": {
# 							"name": "Shaftesbury",
# 							"@id": "https://www.zoopla.co.uk/for-sale/property/shaftesbury/"
# 						},
# 						"@type": "ListItem"
# 					},
# 					{
# 						"position": 5,
# 						"item": {
# 							"name": "Berwick St. John",
# 							"@id": "https://www.zoopla.co.uk/for-sale/property/berwick-st-john/"
# 						},
# 						"@type": "ListItem"
# 					},
# 					{
# 						"position": 6,
# 						"item": {
# 							"name": "Water Street",
# 							"@id": "https://www.zoopla.co.uk/for-sale/property/berwick-st-john/water-street/"
# 						},
# 						"@type": "ListItem"
# 					},
# 					{
# 						"position": 7,
# 						"item": {
# 							"name": "2 bed cottage for sale",
# 							"@id": "https://www.zoopla.co.uk/for-sale/details/59013492/"
# 						},
# 						"@type": "ListItem"
# 					}
# 				],
# 				"@type": "BreadcrumbList"
# 			},
# 			"id": "https://www.zoopla.co.uk/for-sale/details/59013492/",
# 			"@type": "WebPage"
# 		},
# 		{
# 			"@type": "Residence",
# 			"name": "2 bed cottage for sale",
# 			"description": "2 bed cottage for sale in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7, selling for £435,000 from Rural View Residential Sales and Lettings. See property details on Zoopla or browse all our range of properties in Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7.",
# 			"address": {
# 				"@type": "PostalAddress",
# 				"streetAddress": "Berwick St John, Chalke Valley, Wiltshire/Dorset Border SP7",
# 				"addressLocality": "Berwick St. John",
# 				"addressRegion": "South West England"
# 			},
# 			"geo": {
# 				"@type": "GeoCoordinates",
# 				"latitude": 50.9976,
# 				"longitude": -2.078197
# 			},
# 			"photo": [
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/085005e4ba6ca54ecc59cbe7f73e4bf4ece2a333.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/8a6e965e3c79153c9b0410d6f912918e6d08f7d9.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/b880dcc69087f3055cfd27624a539d6e8aaf8fea.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/c0df7625f01afadc133b379c6046bedbf48ad513.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/d8bbf7721540174b36eb74c9bade2be64b567852.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/95a45e8e6b2271d5e4b52aa26578486d90b8e887.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/048dee0161164a73c3ed6b3056a9760e8fb5f8f2.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/2a63b1d76f2b34aed588eab463fb3ff9c18d7b1a.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/7a12ed20b54752c65f2133c1aa6998cdb8d56f4d.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/5d4343a75d717052c84a92ec21003479e7d7c792.jpg"
# 				},
# 				{
# 					"@type": "ImageObject",
# 					"contentUrl": "https://lid.zoocdn.com/1024/768/d80979c18a7e4ab244a9c7b24700f453fcbf4403.jpg"
# 				}
# 			]
# 		}
# 	]
# }</script><link as="image" href="https://lid.zoocdn.com/u/2400/1800/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg" imagesizes="(min-width: 1280px) 800px, (min-width: 960px) 66vw, 100vw" imagesrcset="https://lid.zoocdn.com/u/480/360/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg:p 480w, https://lid.zoocdn.com/u/768/576/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg:p 768w, https://lid.zoocdn.com/u/1024/768/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg:p 1024w, https://lid.zoocdn.com/u/1080/810/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg:p 1080w, https://lid.zoocdn.com/u/1200/900/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg:p 1200w, https://lid.zoocdn.com/u/1600/1200/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg:p 1600w, https://lid.zoocdn.com/u/2400/1800/e080a6a15db275427d4f65fd626ee5d151de9a43.jpg:p 2400w" rel="preload"/><meta content="30" name="next-head-count"/><noscript data-n-css=""></noscript><link as="script" href="https://r.zoocdn.com/_next/static/chunks/main-1588223d01b4ed1b5bb3.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/webpack-533b2d87518b3d44fa16.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/framework.f07dbbe02d5f8878fb39.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/commons.5b7fc982070d4641f261.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/a3ced1229f0578480c60dcdbda3e0264ff016891.f7598b500eb6207fda23.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/a3a337f3edff1c91b9ca0333a68518a69784a60d.615ae4d5d9a7f9d8437f.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/662ceee01ffbb9680f40a88f855a6f7fcc4f6589.f431c491c5a019e8eee0.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/403b7203153773b050df777dee19c0f4162113d1.fef02cbbaa800869996c.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/bcac08a8abfdfd30c00a551cd2ba4e970609b8d4.66c4e456a2acf6a62915.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/032b8b1f8c83b22cbcc54ff4ee1872a0274935ae.b8b504e157751176b5b0.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/663d88a10e7438faa3cfa7f799de4c22baa2495a.fa44348c29ed000b2ad4.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/pages/_app-c3c40d67a1efe30b40a9.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/0b32b42a.9e0ab18cdf99f9e802c4.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/dc0cc0f3.394d29dae1aeef22872e.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/d79a84d7.02f8cb9ec02c06958684.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/83fbce55.bd331b9c464a19550da5.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/02d096a56b196ae07dcd752eb34f1aea20f0bb5a.062808d4478fa09c4eac.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/7ad8b1af83d388d18968c45489d7de9d527f839c.b24e096b76a52d4aeb4e.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/0b6d1d7cf96e007852fffce11d143abe33fdc501.5e348f512fade15059a9.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/5c6b3ec08fdbc6f98e2bb6263405f3303a66e7e1.3738f35d1c139f13c7fa.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/57600b663cf95cfea34099a340c02c8ec6db4b9b.01c54af0ee29d47bb0f1.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/f452e322c41ffd3be56a03c4a5bb11fc9c62ba2d.27fa4267e8b452182cf1.js" rel="preload"/><link as="script" href="https://r.zoocdn.com/_next/static/chunks/59e68a1ab4f6b881447a8e37a30cdae1a663bd38.7f655f1af08ea75f494d.js" rel="preload"/><link as="script" href="http ...
#                 1.5rem - 0.25rem
#             );}}@media only screen and (min-width: 1232px){.css-10eo8n3-Attribute{margin-top:0.5rem;}}.css-8rvu8h-AttributeLabel{white-space:nowrap;}.css-iv63s5-MapContainer{position:relative;width:100%;padding-top:50%;cursor:pointer;}@media only screen and (min-width: 960px){.css-iv63s5-MapContainer{padding-top:31.25%;}}@media only screen and (min-width: 1232px){.css-iv63s5-MapContainer{padding-top:35.35%;}}.css-1md2b5a-MapInner{position:absolute;top:0;left:0;width:100%;height:100%;overflow:hidden;}.css-1md2b5a-MapInner img{position:absolute;top:50%;-webkit-transform:translateY(-50%);-moz-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);width:100%;}.css-coan36-Button-ButtonWithIcon-ExpandButton{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:1px solid transparent;font:inherit;font-weight:bold;-webkit-text-decoration:none;text-decoration:none;letter-spacing:inherit;-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;min-width:140px;text-align:center;-webkit-transition:all 0.2s ease-in-out,background 0.2s linear,box-shadow 0.2s linear;transition:all 0.2s ease-in-out,background 0.2s linear,box-shadow 0.2s linear;cursor:pointer;width:auto;padding:0.75rem 1rem;border-radius:0.25rem;color:#322744;border-color:#322744;background-color:transparent;undefined label:ExpandButton;position:absolute;width:auto;height:auto;top:1rem;right:1rem;background:#fff;border:none;opacity:0.8;padding:0;width:auto;min-width:0;}.css-coan36-Button-ButtonWithIcon-ExpandButton:disabled{color:rgba(50,39,68, 0.4);background-color:#fff;border-color:rgba(50,39,68, 0.4);pointer-events:none;}.css-coan36-Button-ButtonWithIcon-ExpandButton:hover,.css-coan36-Button-ButtonWithIcon-ExpandButton:active{color:#fff;background-color:#322744;border-color:#322744;}.css-coan36-Button-ButtonWithIcon-ExpandButton:focus{outline:none;box-shadow:0 0 0 3px #FAC8F0;}.css-coan36-Button-ButtonWithIcon-ExpandButton:hover:not(:active){-webkit-transform:translateY(-1px);-moz-transform:translateY(-1px);-ms-transform:translateY(-1px);transform:translateY(-1px);box-shadow:0px 0px 0.75rem rgba(50, 39, 68, 0.08),0px 0px 1px rgba(50, 39, 68, 0.32),0px 0.5rem 1rem -0.5rem rgba(50, 39, 68, 0.8);}.css-coan36-Button-ButtonWithIcon-ExpandButton .e1uy4ban0,.css-coan36-Button-ButtonWithIcon-ExpandButton svg{fill:currentColor;margin-right:0.5rem;}.css-coan36-Button-ButtonWithIcon-ExpandButton .e1uy4ban0>svg{margin-right:0;}.css-coan36-Button-ButtonWithIcon-ExpandButton .eczcs4p0{color:currentColor;font-weight:bold;display:block;}@media only screen and (min-width: 768px){.css-coan36-Button-ButtonWithIcon-ExpandButton{right:2rem;}}.css-coan36-Button-ButtonWithIcon-ExpandButton>svg{margin:0;}.css-coan36-Button-ButtonWithIcon-ExpandButton:hover:not(:active){opacity:1;}.css-8moft7-AmenitiesList{padding:0;margin:1.5rem 0;}@media only screen and (min-width: 768px){.css-8moft7-AmenitiesList{-webkit-columns:2;columns:2;-webkit-column-rule:1px solid #D1D0CF;column-rule:1px solid #D1D0CF;-webkit-column-gap:3rem;column-gap:3rem;}}@media only screen and (min-width: 960px){.css-8moft7-AmenitiesList{margin-bottom:0;}}.css-44yosg-AmenityItem{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;break-inside:avoid-column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-text-decoration:none;text-decoration:none;list-style-type:none;margin-bottom:0.5rem;}.css-1rwp6cu-StyledAmenityIcon{margin-right:0.5rem;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-d5xvq9-AmenityTitle{font-weight:no ...
#                 25rem - 1.5rem
#             );}}@media only screen and (min-width: 960px){.css-7a6r2h-SecondaryContent{-webkit-position:sticky;position:sticky;top:1.5rem;left:0;}}.css-wr3nas-Heading3-ListedBy{font-size:1.375rem;font-weight:bold;line-height:1.25;color:#322744;margin:0;margin:1rem 0;}@media only screen and (max-width: 768px){.css-wr3nas-Heading3-ListedBy{font-size:;}}@media only screen and (min-width: 960px){.css-wr3nas-Heading3-ListedBy{display:none;}}.css-5mp4ru-AgentDetailsContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;background-color:#F7F6F5;border-radius:0.25rem;padding:1.5rem 1rem;}.css-5mp4ru-AgentDetailsContainer .e2x51s61{display:none;}@media only screen and (min-width: 960px){.css-5mp4ru-AgentDetailsContainer{background-color:#fff;box-shadow:0px 4px 16px rgba(38, 38, 48, 0.24);}.css-5mp4ru-AgentDetailsContainer .e2x51s61{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-order:3;-ms-flex-order:3;order:3;}}@media only screen and (min-width: 768px){.css-1niyh5b-AgentHeader{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;position:relative;}}@media only screen and (min-width: 960px){.css-1niyh5b-AgentHeader{position:static;}}.css-e13akx-Heading3-AgentHeading{font-size:1.375rem;font-weight:bold;line-height:1.25;color:#322744;margin:0;}@media only screen and (max-width: 768px){.css-e13akx-Heading3-AgentHeading{font-size:;}}@media only screen and (min-width: 768px){.css-e13akx-Heading3-AgentHeading{max-width:calc(100% - 10rem);}}@media only screen and (min-width: 960px){.css-e13akx-Heading3-AgentHeading{-webkit-align-self:start;-ms-flex-item-align:start;align-self:start;max-width:calc(66% - 1rem);margin-right:1rem;}}@media only screen and (min-width: 1232px){.css-e13akx-Heading3-AgentHeading{max-width:calc(60% - 1rem);}}.css-1pbymdb-StyledLink-Link-AgentProperties{line-height:1.625;color:#322744;font-weight:bold;display:inline;border-radius:0.25rem;-webkit-text-decoration:underline;text-decoration:underline;text-decoration-color:#8046F1;text-decoration-thickness:1px;text-underline-position:under;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:1rem;margin-bottom:1rem;}.css-1pbymdb-StyledLink-Link-AgentProperties:focus{outline:0;box-shadow:0 0 0 3px #FAC8F0;}.css-1pbymdb-StyledLink-Link-AgentProperties:hover,.css-1pbymdb-StyledLink-Link-AgentProperties:active{text-decoration-color:#662DBE;}.css-1pbymdb-StyledLink-Link-AgentProperties:hover:not(:active){text-decoration-thickness:2px;}@media only screen and (min-width: 960px){.css-1pbymdb-StyledLink-Link-AgentProperties{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-order:0;-ms-flex-order:0;order:0;white-space:pre;}}@media only screen and (min-width: 768px){.css-rkqh5i-AgentImageLink{-webkit-flex:1 1 100%;-ms-flex:1 1 100%;flex:1 1 100%;position:absolute;top:0;right:0;max-width:9rem;}}@media only screen and (min-width: 960px){.css-rkqh5i-AgentImageLink{max-width:34%;position:static;margin-left:auto;}}@media only screen and (min-width: 1232px){.css-rkqh5i-AgentImageLink{max-width:40%;}}.css-oiz95u-StyledImg-Image-AgentImage{max-width:100%;height:auto;}@media only screen and (min-width: 960px){.css-ovvyt-AgentContact{-webkit-order:2;-ms-flex-order:2;order:2;margin:0.5rem 0 1.5rem 0;border-radius:0.25rem;background-color:#F7F6F5;padding:1rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}.css- ...
# </div><div data-testid="consent-banner"><style>.ui-cookie-consent-overlay button{text-transform:none;-webkit-appearance:button;-moz-appearance:button;appearance:button}.ui-cookie-consent-overlay [type=button]::-moz-focus-inner,.ui-cookie-consent-overlay [type=submit]::-moz-focus-inner,.ui-cookie-consent-overlay button::-moz-focus-inner{border-style:none;padding:0}.ui-cookie-consent-overlay [type=button]:-moz-focusring,.ui-cookie-consent-overlay [type=submit]:-moz-focusring,.ui-cookie-consent-overlay button:-moz-focusring{outline:1px dotted ButtonText}.ui-cookie-consent-overlay *,.ui-cookie-consent-overlay ::after,.ui-cookie-consent-overlay ::before{box-sizing:inherit}svg:not(:root){overflow:hidden}.ui-cookie-consent-overlay [hidden]{display:none}.ui-cookie-consent-overlay .ui-form__label-wrap{color:#262630;font-size:inherit;position:relative;display:block;font-weight:400}.ui-cookie-consent-overlay .ui-form__row{position:relative;display:block}.ui-cookie-consent-overlay .ui-form__check{position:absolute;opacity:0;box-sizing:border-box;padding:0}.ui-cookie-consent-overlay .ui-form__check:active~label,.ui-cookie-consent-overlay .ui-form__check:focus~label,.ui-cookie-consent-overlay .ui-form__check~label:hover{border-color:#322744;cursor:pointer}.ui-cookie-consent-overlay .ui-form__toggle{float:left;margin:15px 0 0;width:1.25em;height:1.25em;text-align:center;border:1px solid #322744;border-radius:.25em;background-color:#fff}.ui-cookie-consent-overlay .ui-button-primary,.ui-cookie-consent-overlay .ui-button-secondary{font:inherit;font-weight:700;letter-spacing:.2px;display:inline-block;padding:.5em 1.25em;text-align:center;border-radius:4px;border:1px solid transparent;text-decoration:none;cursor:pointer;transition:all .2s ease-in-out 0s,background .2s linear 0s,box-shadow .2s linear 0s}.ui-cookie-consent-overlay .ui-button-primary:disabled,.ui-cookie-consent-overlay .ui-button-secondary:disabled{opacity:.4}.ui-cookie-consent-overlay .ui-button-primary:active,.ui-cookie-consent-overlay .ui-button-secondary:active{transform:scale(.95)}.ui-cookie-consent-overlay .ui-button-primary{color:#fff;border-color:#8046f1;background-color:#8046f1}.ui-cookie-consent-overlay .ui-button-primary:hover:not(:disabled){background-color:#662dbe;border-color:#662dbe;transform:translateY(-1px);box-shadow:rgb(50 39 68 / 8%) 0 0 .75rem,rgb(50 39 68 / 32%) 0 0 1px,rgb(50 39 68 / 80%) 0 .5rem 1rem -.5rem}.ui-cookie-consent-overlay .ui-button-primary:focus:not(:disabled){outline:0;box-shadow:rgb(250 200 240) 0 0 0 3px}.ui-cookie-consent-overlay .ui-button-secondary{color:#322744;border-color:#322744;background-color:#fff}.ui-cookie-consent-overlay .ui-button-secondary:hover:not(:disabled){color:#fff;border-color:#322744;background-color:#322744;transform:translateY(-1px);box-shadow:rgb(50 39 68 / 8%) 0 0 .75rem,rgb(50 39 68 / 32%) 0 0 1px,rgb(50 39 68 / 80%) 0 .5rem 1rem -.5rem}.ui-cookie-consent-overlay .ui-button-secondary:focus:not(:disabled){outline:0;box-shadow:rgb(250 200 240) 0 0 0 3px}.ui-cookie-consent-overlay .ui-cookie-consent,.ui-cookie-consent-overlay .ui-cookie-consent p{font:normal 16px/1.5 Arial,sans-serif;text-align:left;letter-spacing:.2px}.ui-cookie-consent-overlay .ui-cookie-consent,.ui-cookie-consent-overlay .ui-cookie-consent h2,.ui-cookie-consent-overlay .ui-cookie-consent p{font-family:Arial,sans-serif}.ui-cookie-consent-overlay .ui-cookie-consent h2{font-family:Lato,Arial,sans-serif}.ui-cookie-consent-overlay .ui-cookie-consent a{color:#322744;font-weight:700;text-decoration:underline;-webkit-text-decoration-color:#8046f1;text-decoration-color:#8046f1;text-decoration-thickness:1px;text-underline-position:under}.ui-cookie-consent-overlay .ui-cookie-consent a:active,.ui-cookie-consent-overlay .ui-cookie-consent a:hover{text-decoration:underline;-webkit-text-decoration-color:#662dbe;text-decoration-color:#662dbe;text-decoration-thickness:2px}.ui-cookie-consent-overlay .ui-cookie-consent a:active{text-decoration-thickness:1px}.ui-cookie ...
# <div hidden="" id="ui-cookie-consent-overlay-wrap"> <div class="ui-cookie-consent-overlay"> <form action="/privacy/cookie-policy/" class="ui-form ui-cookie-consent" data-overlay-context="overlay" data-segment-appid="kMettuB218zyYLIzUsT2ptxdGiEtWYT2" id="cookie-consent-form"> <section class="ui-cookie-consent-main"> <h2 class="ui-title-group"> Your cookie preferences </h2> <p>We use cookies and similar technologies on Zoopla. You can use the settings below to accept all cookies (which we recommend to give you the best online personalised experience) or to enable specific categories of cookies as explained below. You can change your settings at any time and find out more by visiting our <a class="ui-link" data-ajax="false" data-name="policyPageLink" href="/privacy/cookie-policy/">Cookie Policy</a>, which also explains why some cookies, that can't be turned off, are required to operate our website more effectively.</p> <div class="ui-form__row ui-cookie-accept-all-small"> <button class="ui-button-primary" data-responsibility="acceptAll" type="button">Accept all cookies</button> </div> </section> <div class="ui-cookie-consent-choose-wrap"> <div class="ui-cookie-consent-choose"> <fieldset class="ui-form__fieldset"> <div class="ui-form__row"> <input checked="checked" class="ui-form__check" data-analytics-label="necessary" data-numeric-category-id="1" disabled="disabled" id="necessary" type="checkbox" value="true"/> <span class="ui-form__toggle"> <svg class="ui-cookie-consent_tick-svg" focusable="false" height="14px" version="1.1" viewbox="0 0 24 24" width="12px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <g fill-rule="evenodd" stroke="none" stroke-width="1"> <g transform="translate(-72.000000, -192.000000)"> <path d="M79.7995,214.349777 C79.4035,214.349777 79.0215,214.192777 78.7385,213.910777 L72.4395,207.610777 C71.8535,207.024777 71.8535,206.075777 72.4395,205.489777 C73.0255,204.903777 73.9745,204.903777 74.5605,205.489777 L79.6925,210.620777 L93.3415,194.046777 C93.8685,193.406777 94.8135,193.315777 95.4525,193.841777 C96.0925,194.369777 96.1845,195.314777 95.6575,195.953777 L80.9575,213.802777 C80.6885,214.129777 80.2945,214.327777 79.8715,214.347777 C79.8475,214.348777 79.8235,214.349777 79.7995,214.349777" id="Fill-52"></path> </g> </g> </svg> </span> <label class="ui-form__label-wrap" for="necessary">Necessary</label> </div> <div class="ui-form__row"> <input class="ui-form__check" data-analytics-label="advertising" data-numeric-category-id="3" id="advertising" type="checkbox" value="true"/> <span class="ui-form__toggle"> <svg class="ui-cookie-consent_tick-svg" focusable="false" height="14px" version="1.1" viewbox="0 0 24 24" width="12px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <g fill-rule="evenodd" stroke="none" stroke-width="1"> <g transform="translate(-72.000000, -192.000000)"> <path d="M79.7995,214.349777 C79.4035,214.349777 79.0215,214.192777 78.7385,213.910777 L72.4395,207.610777 C71.8535,207.024777 71.8535,206.075777 72.4395,205.489777 C73.0255,204.903777 73.9745,204.903777 74.5605,205.489777 L79.6925,210.620777 L93.3415,194.046777 C93.8685,193.406777 94.8135,193.315777 95.4525,193.841777 C96.0925,194.369777 96.1845,195.314777 95.6575,195.953777 L80.9575,213.802777 C80.6885,214.129777 80.2945,214.327777 79.8715,214.347777 C79.8475,214.348777 79.8235,214.349777 79.7995,214.349777" id="Fill-52"></path> </g> </g> </svg> </span> <label class="ui-form__label-wrap" for="advertising">Tailored advertising</label> </div> <div class="ui-form__row"> <input class="ui-form__check" data-analytics-label="functionality" data-numeric-category-id="4" id="functionality" type="checkbox" value="true"/> <span class="ui-form__toggle"> <svg class="ui-cookie-consent_tick-svg" focusable="false" height="14px" version="1.1" viewbox="0 0 24 24" width="12px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <g fill-rule="evenodd" stroke="none"  ...
# <script type="text/javascript">!function(e){var t={};function n(o){if(t[o])return t[o].exports;var r=t[o]={i:o,l:!1,exports:{}};return e[o].call(r.exports,r,r.exports,n),r.l=!0,r.exports}n.m=e,n.c=t,n.d=function(e,t,o){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:o})},n.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&t&&(e=n(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var o=Object.create(null);if(n.r(o),Object.defineProperty(o,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var r in e)n.d(o,r,function(t){return e[t]}.bind(null,r));return o},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="",n(n.s=1)}([function(e,t){self.fetch||(self.fetch=function(e,t){return t=t||{},new Promise((function(n,o){var r=new XMLHttpRequest,c=[],s=[],i={},a=function(){return{ok:2==(r.status/100|0),statusText:r.statusText,status:r.status,url:r.responseURL,text:function(){return Promise.resolve(r.responseText)},json:function(){return Promise.resolve(r.responseText).then(JSON.parse)},blob:function(){return Promise.resolve(new Blob([r.response]))},clone:a,headers:{keys:function(){return c},entries:function(){return s},get:function(e){return i[e.toLowerCase()]},has:function(e){return e.toLowerCase()in i}}}};for(var u in r.open(t.method||"get",e,!0),r.onload=function(){r.getAllResponseHeaders().replace(/^(.*?):[^\S\n]*([\s\S]*?)$/gm,(function(e,t,n){c.push(t=t.toLowerCase()),s.push([t,n]),i[t]=i[t]?i[t]+","+n:n})),n(a())},r.onerror=o,r.withCredentials="include"==t.credentials,t.headers)r.setRequestHeader(u,t.headers[u]);r.send(t.body||null)}))})},function(e,t,n){"use strict";n.r(t);const o=[];function r(e,t){if("string"!=typeof e)throw new Error("Published event name must be a string");if(t&&t instanceof Object!=!0)throw new Error("Published data must be an object");let n=!1;const r=o.length;for(let c=0;c<r;c++)o[c]&&o[c].eventName===e&&(o[c].handler.call(this,t),n=!0);return n}function c(e,t){if("string"!=typeof e)throw new Error("Event name must be a string");if("function"!=typeof t)throw new Error("Event handler must be a function");const n=o.length;for(let r=0;r<n;r++)if(o[r]&&o[r].eventName===e&&o[r].handler===t)return!1;return o.push({eventName:e,handler:t}),!0}window.ZPG&&window.ZPG.stickyBars||(window.ZPG||(window.ZPG={}),window.ZPG.stickyBars=[]);function s(e,t,n={}){const o=new Date,r=n.daysToExpire||365,c=n.domain||"zoopla.co.uk",s=n.path||"/";o.setTime(Number(o)+864e5*r),document.cookie=`${e}=${t};expires=${o.toGMTString()};path=${s};domain=${c};`}function i(e){const t=document.cookie.match(new RegExp(`\\b${e}=([^;]+)`));return t?t[1]:null}var a={setItem:function(e,t,n=!1,o){if(n)s(e,t,o);else try{localStorage.setItem(e,t)}catch(n){s(e,t,o)}},getItem:function(e,t=!1){if(t)return i(e);try{return localStorage.getItem(e)}catch(t){return i(e)}},removeItem:function(e,t={}){const n=t.domain||"zoopla.co.uk",o=`${e}=;expires=Thu, 01 Jan 1970 00:00:01 GMT;path=${t.path||"/"};domain=${n};`;try{localStorage.removeItem(e),i(e)&&(document.cookie=o)}catch(t){i(e)&&(document.cookie=o)}}};window.ZPG=window.ZPG||{},window.ZPG.UI=window.ZPG.UI||{},window.ZPG.UI.lazyElements=[];window.ZPG.UI.lazyElements;function u(e){return{trapStart:e.querySelector("[data-focus-trap='start']"),trapEnd:e.querySelector("[data-focus-trap='end']")}}function l(e,t,n){const{trapStart:o,trapEnd:r}=function(){const e=document.createElement("div"),t=document.createElement("div");return e.setAttribute("data-focus-trap","start"),t.setAttribute("data-focus-trap","end"),e.tabIndex=0,t.tabIndex=0,{trapStart:e,trapEnd:t}}();e.insertAdjacentHTML("afterbegin",o.outerHTML),e.insertAdjacentHTML("beforeend",r.outerHTML),e.addEventListener("focus",t,!0),e.addEventListen ...
#                         of this property<!-- -->.</p><button class="css-y70zki-Button eaqu47p0" data-testid="floorplan-block-link">View floor plan</button></div></div><div class="css-8ue4tr-MoreInformationWrapper e11u8tx30" data-testid="listing-more-information"><h3 class="css-14i1dnm-Heading3 e1s8jdjv3" size="6">More information</h3><button class="eo4v3t1 css-x15t68-ContainerButton-CTAButton e1wtrmg02" data-testid="floorplans-button"><svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.875.125a1.75 1.75 0 00-1.75 1.75v16.25c0 .967.784 1.75 1.75 1.75h16.25a1.75 1.75 0 001.75-1.75v-6.517a1.75 1.75 0 00-1.75-1.75h-7.283V7.24a.75.75 0 00-1.5 0v2.62h-2.33a.75.75 0 000 1.5h2.33v.531l-1.607 1.62A.75.75 0 008.8 14.567l1.829-1.844a.749.749 0 00.213-.605v-.76h7.283a.25.25 0 01.25.25v6.517a.25.25 0 01-.25.25h-7.3c.011-.082.017-.165.017-.25V16.13a.75.75 0 00-1.5 0v1.995a.25.25 0 01-.25.25H1.875a.25.25 0 01-.25-.25v-6.517a.25.25 0 01.25-.25h1.318a.75.75 0 000-1.5H1.875c-.085 0-.168.006-.25.018V1.875a.25.25 0 01.25-.25h7.217a.25.25 0 01.25.25v1.276l-1.607 1.62A.75.75 0 008.8 5.828l1.671-1.685a.75.75 0 00.37-.593.752.752 0 00.001-.171V1.875a1.75 1.75 0 00-1.75-1.75H1.875z" fill-rule="evenodd"></path></svg><span class="css-1112zi5-Label e1wtrmg00">Floor plans</span><svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M7.47 15.53a.75.75 0 010-1.06L11.94 10 7.47 5.53a.75.75 0 011.06-1.06l5 5a.75.75 0 010 1.06l-5 5a.75.75 0 01-1.06 0z" fill-rule="evenodd"></path></svg></button><button class="eo4v3t1 css-x15t68-ContainerButton-CTAButton e1wtrmg02" data-testid="listinghistory-button"><svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M17.841 2.091c.14.14.22.331.22.53V6a.75.75 0 01-1.5 0V4.438a.766.766 0 01-.048.041l-5.446 4.357a.75.75 0 01-.941-.004l-4.005-3.25-2.669 2.016a.75.75 0 11-.904-1.196L5.686 4.03a.75.75 0 01.925.017l3.991 3.24 4.895-3.916h-1.429a.75.75 0 010-1.5h3.243a.75.75 0 01.53.22zM1.5 9.25c-.69 0-1.25.56-1.25 1.25v8c0 .69.56 1.25 1.25 1.25h3c.69 0 1.25-.56 1.25-1.25v-8c0-.69-.56-1.25-1.25-1.25h-3zm.25 9v-7.5h2.5v7.5h-2.5zm5.5-4.75c0-.69.56-1.25 1.25-1.25h3c.69 0 1.25.56 1.25 1.25v5c0 .69-.56 1.25-1.25 1.25h-3c-.69 0-1.25-.56-1.25-1.25v-5zm1.5.25v4.5h2.5v-4.5h-2.5zm6.75-5.5c-.69 0-1.25.56-1.25 1.25v9c0 .69.56 1.25 1.25 1.25h3c.69 0 1.25-.56 1.25-1.25v-9c0-.69-.56-1.25-1.25-1.25h-3zm.25 10v-8.5h2.5v8.5h-2.5z" fill-rule="evenodd"></path></svg><span class="css-1112zi5-Label e1wtrmg00">Listing history</span><svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M7.47 15.53a.75.75 0 010-1.06L11.94 10 7.47 5.53a.75.75 0 011.06-1.06l5 5a.75.75 0 010 1.06l-5 5a.75.75 0 01-1.06 0z" fill-rule="evenodd"></path></svg></button><button class="eo4v3t1 css-x15t68-ContainerButton-CTAButton e1wtrmg02" data-testid="additionallinks-button"><svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M3.137.188c-.69 0-1.25.56-1.25 1.25v17.125c0 .69.56 1.25 1.25 1.25h13.727c.69 0 1.25-.56 1.25-1.25V5.969a1.25 1.25 0 00-.005-.11.754.754 0 00-.261-.661 1.267 1.267 0 00-.072-.084L13.528.583a1.24 1.24 0 00-.087-.085.749.749 0 00-.703-.305 1.251 1.251 0 00-.122-.006H3.137zm8.946 1.5H3.387v16.625h13.227V6.52h-3.28c-.691 0-1.25-.56-1.25-1.25V1.688zm3.55 3.333l-2.05-2.187v2.187h2.05zM5.286 13.625a.75.75 0 01.75-.75h7.93a.75.75 0 010 1.5h-7.93a.75.75 0 01-.75-.75zm1.316-4.3a.75.75 0 100 1.5h3.399a.75.75 0 100-1.5H6.602z" fill-rule="evenodd"></path></svg><span class="css-1112zi5-Label e1wtrmg00">Additional links</span><svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M7.47 15.53a.75.75 0 010-1.06L11. ...

# %%
# price = [item for item in soup.find_all('a', attrs={'data-testid' : True}) if item['data-testid']=='listing-details-link']
prices = [item for item in soup.find_all('span', attrs={'data-testid' : True}) if item['data-testid']=='price' and 'pcm' in item.text]

final_pcm = None
for p in prices:
    print(p.get_text())
    final_pcm = p.get_text()

# %%
final_pcm[1:-4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9aff78edae5c> in <module>
# ----> 1 final_pcm[1:-4]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
baths = [item for item in soup.find_all('span', attrs={'data-testid' : 'price'})]

for tag in baths:
    baths = tag.get_text()
    baths = baths.split(' ')[0]
    print(baths)
# Out:
# £435,000

# %%
try:
    tags = [item for item in soup.find_all('span', attrs={'data-testid' : 'price'})]

    for tag in tags:
        data = tag.get_text()
        data = data[1:]
        data=data.replace(',','')
        print(data)
except:
    None
# Out:
# 435000
